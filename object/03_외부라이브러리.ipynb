# %%
# Do not reinvert the wheel

# %%
from faker import Faker # Faker: 가짜 데이터를 만들어주는 라이브러리

fake = Faker()
fake.name()
# Out:
# 'John Owens'

# %%
fake.address()
# Out:
# '301 Tyler Port Suite 605\nNew Robert, TX 57249'

# %%
test_data = [(fake.name(), fake.address()) for _ in range(30)]
print(test_data)
# Out:
# [('Jennifer Payne', '25312 Jennifer Corners\nAshleyview, GU 62994'), ('Derrick Hernandez', '92881 Orozco Fords\nRyanview, IA 14311'), ('Yvonne Anderson', '02480 Felicia Passage Suite 546\nJonesberg, MT 73049'), ('Cynthia Townsend', '6337 Scott Shores Suite 036\nLake Ronaldport, NC 60117'), ('Brent Nelson', 'USNS Jackson\nFPO AP 09185'), ('Ashley Sanchez', '7037 Michael Extension Suite 769\nHarveybury, SC 34378'), ('Greg Fisher', '30413 Smith Stravenue Apt. 790\nLake Candacetown, VT 55071'), ('Tanya Rogers', '644 Donna Rapids\nEast Laura, NH 85146'), ('Daniel Russell MD', '493 Donna Rapid\nScottmouth, PR 91196'), ('Alexis Bell', '30302 Pham Station\nRyanside, MS 13482'), ('Luis Le', '9216 Martin Club Apt. 292\nWest Charlesstad, NC 57104'), ('John Simmons', '4701 Robin Extensions Suite 141\nSeanfort, TN 68281'), ('Derek Cline', '07575 Christopher Manors\nHernandezland, FL 75603'), ('Kimberly Daniel', '1344 Jordan Junctions\nCunninghamborough, LA 50925'), ('Dennis Jenkins', '192 William
# ...
