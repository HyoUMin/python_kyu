# %%
# module1.py 불러오기

import module1

print(module1.add(3, 4))
print(module1.sub(3, 4))
# Out:
# 7
# -1

# %%
# 모듈 안 메소드를 바로 가져오기
from module1 import add, sub  # from module1 import *  모듈 안 모든 메소드 불러오기 
print(add(3, 2))
print(sub(3, 2))
# Out:
# 5
# 1
