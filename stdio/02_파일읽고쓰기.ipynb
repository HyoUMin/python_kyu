# %%
#  파일 생성하기

f = open("새 파일.txt", "w")
f.close()

# %%
f = open("새 파일1.txt", "w") # f는 변수 아님. 객체로 생각해야 함. 파일 객체라고도 불림
for i in range(1, 11):
    data = f"{i}번째 줄입니다.\n"
    f.write(data)
f.close()
